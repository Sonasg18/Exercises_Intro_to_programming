# %%
x = 5
country = Switzerland
print(country)
country ="Switzerland"
inflation_rate = 1.2

# This calcualtes the Interest rate
nominal_rate = 5.0 
inflation = 2.0 
real_rate = nominal_rate - inflation # you can also add comments at the end of the line 
 
country = "Japan"
unemployment = 2.6 
print(f"the unemployment rate in {country} is currently {unemployment}%.")
