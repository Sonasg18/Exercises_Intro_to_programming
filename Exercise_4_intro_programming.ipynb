# %%
a = "15"
b = 4
c = 2.5 
d = False

print(type(a))
print(type(b))
print(type(c))
print(type(d))

#How can I add a and b

#convert string to integer first
added = int(a) + b
print(added)

#convert boolean to integer 
d_integer = int(d)
print(d_integer)

animals = ["cat", "dog", "rabbit", "horse"]
print(animals[0])
print(animals[1])
print(animals[-1])
animals.append("hamster")
print(animals)
animals.remove("rabbit")
print(animals)

5 > 3 and 2 < 1
10 == "10"
not (4 >= 4)
"cat" in ["dog", "cat", "bird"]
print("line 1:", 5 > 3 and 2 < 1)
print("line 2:", 10 == 10)
print("line 2:", 10 == "10")
print("line3:", not (4 >= 4))

temperature = 18
if temperature < 18:
    print("Cold")
elif temperature <= 20:
    print("Mild")
else:
    print("Warm")

numbers = [4, 7, 1, 9, 2]

# 1 Print each number 
for n in numbers:
    print(n)

# 2) print numbers only greater than 5
for n in numbers:
    if n > 5:
        print(n)

# 3) compute the sum of all numbers using a loop
total = 0
for n in numbers: 
    total = total + n #or you can do total += n
    print(total)
    print("sum:", total)

orders = [120, 45, 300, 89, 15, 220, 60, 500, 75]
print(orders[0])
print(orders[-1])
print(len(orders))
print(max(orders))

#print all orders above a 100
for order in orders:
    if order > 100:
        print(order)

# 2) count how many orders below 50 
count_below_50 = 0
for order in orders: 
    if order < 50:
        count_below_50 += 1
print(count_below_50)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 19
# 0
# cat
# dog
# horse
# ['cat', 'dog', 'rabbit', 'horse', 'hamster']
# ['cat', 'dog', 'horse', 'hamster']
# line 1: False
# line 2: True
# line 2: False
# line3: False
# Mild
# 4
# 7
# 1
# 9
# 2
# 7
# 9
# 4
# sum: 4
# 11
# sum: 11
# 12
# sum: 12
# 21
# sum: 21
# 23
# sum: 23
# 120
# 75
# 9
# 500
# 120
# 300
# 220
# 500
# 2
